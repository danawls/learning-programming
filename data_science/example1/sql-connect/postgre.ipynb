# %%
secret = 'woojin20110105@'
import psycopg2 as pg2
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = pg2.connect(database='dvdrental', user='postgres', password=secret)

# %%
cur = conn.cursor()

# %%
cur.execute('SELECT customer_id, SUM(amount) FROM payment GROUP BY customer_id ORDER BY customer_id ASC')

# %%
data = cur.fetchall()
data
# Out:
# [(1, Decimal('114.70')),
#  (2, Decimal('123.74')),
#  (3, Decimal('130.76')),
#  (4, Decimal('81.78')),
#  (5, Decimal('134.65')),
#  (6, Decimal('84.75')),
#  (7, Decimal('130.72')),
#  (8, Decimal('85.77')),
#  (9, Decimal('78.80')),
#  (10, Decimal('94.76')),
#  (11, Decimal('99.77')),
#  (12, Decimal('93.74')),
#  (13, Decimal('131.73')),
#  (14, Decimal('96.77')),
#  (15, Decimal('134.68')),
#  (16, Decimal('109.75')),
#  (17, Decimal('87.82')),
#  (18, Decimal('78.81')),
#  (19, Decimal('98.82')),
#  (20, Decimal('103.73')),
#  (21, Decimal('146.68')),
#  (22, Decimal('94.81')),
#  (23, Decimal('106.73')),
#  (24, Decimal('85.77')),
#  (25, Decimal('104.73')),
#  (26, Decimal('146.68')),
#  (27, Decimal('123.70')),
#  (28, Decimal('105.70')),
#  (29, Decimal('138.65')),
#  (30, Decimal('123.66')),
#  (31, Decimal('104.74')),
#  (32, Decimal('112.74')),
#  (33, Decimal('88.80')),
#  (34, Decimal('89.76')),
#  (35, Decimal('118.70')),
#  (36, Decimal('90.75')),
#  (37, Decimal('91.79')),
#  (38, Decimal('127.66')),
#  (39, Decimal('141.71')),
#  (40, Decimal('105.74')),
#  (41, Decimal('118.75')),
#  (42, Decimal('111.71')),
#  (43, Decimal('89.78')),
#  (44, Decimal('101.79')),
#  (45, Decimal('124.74')),
#  (46, Decimal('131.69')),
#  (47, Decimal('92.81')),
#  (48, Decimal('67.86')),
#  (49, Decimal('116.76')),
#  (50, Decimal('144.70')),
#  (51, Decimal('123.70')),
#  (52, Decimal('106.72')),
#  (53, Decimal('88.76')),
#  (54, Decimal('114.74')),
#  (55, Decimal('84.81')),
#  (56, Decimal('115.74')),
#  (57, Decimal('99.74')),
#  (58, Decimal('105.76')),
#  (59, Decimal('119.76')),
#  (60, Decimal('88.78')),
#  (61, Decimal('57.87')),
#  (62, Decimal('78.79')),
#  (63, Decimal('112.75')),
#  (64, Decimal('91.70')),
#  (65, Decimal('97.80')),
#  (66, Decimal('139.67')),
#  (67, Decimal('86.80')),
#  (68, Decimal('94.78')),
#  (69, Decimal('89.77')),
#  (70, Decimal('75.83')),
#  (71, Decimal('116.72')),
#  (72, Decimal('88.73')),
#  (73, Decimal('89.78')),
#  (74, Decimal('96.74')),
#  (75, Decimal('149.61')),
#  (76, Decimal('74.79')),
#  (77, Decimal('85.77')),
#  (78, Decimal('141.69')),
#  (79, Decimal('73.81')),
#  (80, Decimal('137.70')),
#  (81, Decimal('92.79')),
#  (82, Decimal('118.76')),
#  (83, Decimal('96.78')),
#  (84, Decimal('128.70')),
#  (85, Decimal('72.79')),
#  (86, Decimal('146.68')),
#  (87, Decimal('137.72')),
#  (88, Decimal('84.80')),
#  (89, Decimal('124.71')),
#  (90, Decimal('110.72')),
#  (91, Decimal('107.66')),
#  (92, Decimal('122.74')),
#  (93, Decimal('76.80')),
#  (94, Decimal('71.81')),
#  (95, Decimal('72.83')),
#  (96, Decimal('105.73')),
#  (97, Decimal('58.82')),
#  (98, Decimal('102.76')),
#  (99, Decimal('90.77')),
#  (100, Decimal('101.77')),
#  (101, Decimal('86.77')),
#  (102, Decimal('129.70')),
#  (103, Decimal('128.71')),
#  (104, Decimal('77.78')),
#  (105, Decimal('93.78')),
#  (106, Decimal('95.79')),
#  (107, Decimal('114.72')),
#  (108, Decimal('126.72')),
#  (109, Decimal('79.81')),
#  (110, Decimal('49.88')),
#  (111, Decimal('94.75')),
#  (112, Decimal('129.72')),
#  (113, Decimal('111.73')),
#  (114, Decimal('126.70')),
#  (115, Decimal('86.73')),
#  (116, Decimal('106.74')),
#  (117, Decimal('69.83')),
#  (118, Decimal('76.80')),
#  (119, Decimal('139.69')),
#  (120, Decimal('134.70')),
#  (121, Decimal('104.75')),
#  (122, Decimal('120.70')),
#  (123, Decimal('97.77')),
#  (124, Decimal('57.86')),
#  (125, Decimal('131.69')),
#  (126, Decimal('102.75')),
#  (127, Decimal('105.78')),
#  (128, Decimal('118.70')),
#  (129, Decimal('124.66')),
#  (130, Decimal('87.78')),
#  (131, Decimal('112.73')),
#  (132, Decimal('95.72')),
#  (133, Decimal('88.75')),
#  (134, Decimal('77.81')),
#  (135, Decimal('100.72')),
#  (136, Decimal('59.86')),
#  (137, Decimal('191.62')),
#  (138, Decimal('106.68')),
#  (139, Decimal('113.73')),
#  (140, Decimal('83.82')),
#  (141, Decimal('127.69')),
#  (142, Decimal('74.77')),
#  (143, Decimal('83.80')),
#  (144, Decimal('189.60')),
#  (145, Decimal('107.73')),
#  (146, Decimal('126.73')),
#  (147, Decimal('125.68')),
#  (148, Decimal('211.55')),
#  (149, Decimal('116.75')),
#  (150, Decimal('94.78')),
#  (151, Decimal('81.75')),
#  (152, Decimal('73.81')),
#  (153, Decimal('94.76')),
#  (154, Decimal('110.73')),
#  (155, Decimal('106.76')),
#  (156, Decimal('89.77')),
#  (157, Decimal('107.71')),
#  (158, Decimal('115.70')),
#  (159, Decimal('58.83')),
#  (160, Decimal('106.73')),
#  (161, Decimal('94.76')),
#  (162, Decimal('59.83')),
#  (163, Decimal('122.71')),
#  (164, Decimal('64.85')),
#  (165, Decimal('81.80')),
#  (166, Decimal('121.73')),
#  (167, Decimal('108.71')),
#  (168, Decimal('129.68')),
#  (169, Decimal('86.80')),
#  (170, Decimal('109.77')),
#  (171, Decimal('104.75')),
#  (172, Decimal('133.70')),
#  (173, Decimal('111.73')),
#  (174, Decimal('81.81')),
#  (175, Decimal('98.76')),
#  (176, Decimal('151.68')),
#  (177, Decimal('71.77')),
#  (178, Decimal('194.61')),
#  (179, Decimal('120.74')),
#  (180, Decimal('95.78')),
#  (181, Decimal('167.67')),
#  (182, Decimal('92.76')),
#  (183, Decimal('75.78')),
#  (184, Decimal('80.80')),
#  (185, Decimal('79.80')),
#  (186, Decimal('111.71')),
#  (187, Decimal('151.73')),
#  (188, Decimal('92.75')),
#  (189, Decimal('87.79')),
#  (190, Decimal('102.75')),
#  (191, Decimal('66.82')),
#  (192, Decimal('97.78')),
#  (193, Decimal('105.77')),
#  (194, Decimal('74.84')),
#  (195, Decimal('86.81')),
#  (196, Decimal('128.69')),
#  (197, Decimal('133.68')),
#  (198, Decimal('124.68')),
#  (199, Decimal('95.76')),
#  (200, Decimal('126.74')),
#  (201, Decimal('91.78')),
#  (202, Decimal('103.74')),
#  (203, Decimal('87.81')),
#  (204, Decimal('134.69')),
#  (205, Decimal('80.82')),
#  (206, Decimal('126.73')),
#  (207, Decimal('119.72')),
#  (208, Decimal('86.75')),
#  (209, Decimal('147.71')),
#  (210, Decimal('134.70')),
#  (211, Decimal('146.67')),
#  (212, Decimal('91.80')),
#  (213, Decimal('110.73')),
#  (214, Decimal('103.74')),
#  (215, Decimal('81.76')),
#  (216, Decimal('90.78')),
#  (217, Decimal('86.79')),
#  (218, Decimal('67.82')),
#  (219, Decimal('100.75')),
#  (220, Decimal('109.75')),
#  (221, Decimal('127.73')),
#  (222, Decimal('71.84')),
#  (223, Decimal('77.84')),
#  (224, Decimal('76.78')),
#  (225, Decimal('111.76')),
#  (226, Decimal('87.79')),
#  (227, Decimal('78.78')),
#  (228, Decimal('86.75')),
#  (229, Decimal('93.75')),
#  (230, Decimal('118.69')),
#  (231, Decimal('88.77')),
#  (232, Decimal('86.77')),
#  (233, Decimal('89.77')),
#  (234, Decimal('106.75')),
#  (235, Decimal('89.77')),
#  (236, Decimal('166.61')),
#  (237, Decimal('138.69')),
#  (238, Decimal('86.81')),
#  (239, Decimal('108.72')),
#  (240, Decimal('106.77')),
#  (241, Decimal('110.68')),
#  (242, Decimal('128.71')),
#  (243, Decimal('77.77')),
#  (244, Decimal('122.70')),
#  (245, Decimal('103.74')),
#  (246, Decimal('76.82')),
#  (247, Decimal('88.81')),
#  (248, Decimal('37.87')),
#  (249, Decimal('88.81')),
#  (250, Decimal('54.85')),
#  (251, Decimal('100.75')),
#  (252, Decimal('58.80')),
#  (253, Decimal('116.74')),
#  (254, Decimal('107.70')),
#  (255, Decimal('70.82')),
#  (256, Decimal('97.75')),
#  (257, Decimal('142.66')),
#  (258, Decimal('110.76')),
#  (259, Decimal('154.70')),
#  (260, Decimal('113.70')),
#  (261, Decimal('90.78')),
#  (262, Decimal('114.73')),
#  (263, Decimal('116.73')),
#  (264, Decimal('98.75')),
#  (265, Decimal('132.72')),
#  (266, Decimal('113.74')),
#  (267, Decimal('142.67')),
#  (268, Decimal('96.79')),
#  (269, Decimal('96.79')),
#  (270, Decimal('75.81')),
#  (271, Decimal('56.84')),
#  (272, Decimal('65.87')),
#  (273, Decimal('130.72')),
#  (274, Decimal('116.73')),
#  (275, Decimal('92.75')),
#  (276, Decimal('94.77')),
#  (277, Decimal('108.76')),
#  (278, Decimal('71.79')),
#  (279, Decimal('114.76')),
#  (280, Decimal('103.77')),
#  (281, Decimal('32.90')),
#  (282, Decimal('79.80')),
#  (283, Decimal('68.77')),
#  (284, Decimal('108.78')),
#  (285, Decimal('117.77')),
#  (286, Decimal('96.76')),
#  (287, Decimal('80.78')),
#  (288, Decimal('52.81')),
#  (289, Decimal('104.76')),
#  (290, Decimal('80.78')),
#  (291, Decimal('73.83')),
#  (292, Decimal('102.78')),
#  (293, Decimal('107.79')),
#  (294, Decimal('105.77')),
#  (295, Decimal('125.72')),
#  (296, Decimal('103.77')),
#  (297, Decimal('99.74')),
#  (298, Decimal('78.79')),
#  (299, Decimal('84.79')),
#  (300, Decimal('123.74')),
#  (301, Decimal('71.85')),
#  (302, Decimal('113.74')),
#  (303, Decimal('70.81')),
#  (304, Decimal('79.81')),
#  (305, Decimal('87.80')),
#  (306, Decimal('119.72')),
#  (307, Decimal('92.80')),
#  (308, Decimal('81.81')),
#  (309, Decimal('113.75')),
#  (310, Decimal('68.87')),
#  (311, Decimal('80.85')),
#  (312, Decimal('81.80')),
#  (313, Decimal('63.84')),
#  (314, Decimal('113.71')),
#  (315, Decimal('67.86')),
#  (316, Decimal('80.81')),
#  (317, Decimal('96.76')),
#  (318, Decimal('27.93')),
#  (319, Decimal('93.79')),
#  (320, Decimal('47.85')),
#  (321, Decimal('93.83')),
#  (322, Decimal('81.81')),
#  (323, Decimal('91.75')),
#  (324, Decimal('95.78')),
#  (325, Decimal('72.82')),
#  (326, Decimal('64.82')),
#  (327, Decimal('74.81')),
#  (328, Decimal('65.83')),
#  (329, Decimal('98.77')),
#  (330, Decimal('60.82')),
#  (331, Decimal('105.78')),
#  (332, Decimal('107.74')),
#  (333, Decimal('89.78')),
#  (334, Decimal('108.75')),
#  (335, Decimal('73.78')),
#  (336, Decimal('93.78')),
#  (337, Decimal('111.76')),
#  (338, Decimal('78.80')),
#  (339, Decimal('95.76')),
#  (340, Decimal('83.77')),
#  (341, Decimal('103.78')),
#  (342, Decimal('130.68')),
#  (343, Decimal('106.77')),
#  (344, Decimal('64.84')),
#  (345, Decimal('104.79')),
#  (346, Decimal('145.70')),
#  (347, Decimal('142.70')),
#  (348, Decimal('144.66')),
#  (349, Decimal('133.72')),
#  (350, Decimal('63.79')),
#  (351, Decimal('87.77')),
#  (352, Decimal('96.78')),
#  (353, Decimal('65.83')),
#  (354, Decimal('125.67')),
#  (355, Decimal('68.81')),
#  (356, Decimal('116.71')),
#  (357, Decimal('80.77')),
#  (358, Decimal('75.80')),
#  (359, Decimal('85.78')),
#  (360, Decimal('144.68')),
#  (361, Decimal('89.71')),
#  (362, Decimal('140.69')),
#  (363, Decimal('139.72')),
#  (364, Decimal('89.78')),
#  (365, Decimal('92.79')),
#  (366, Decimal('145.64')),
#  (367, Decimal('97.80')),
#  (368, Decimal('139.69')),
#  (369, Decimal('69.79')),
#  (370, Decimal('70.81')),
#  (371, Decimal('123.71')),
#  (372, Decimal('152.68')),
#  (373, Decimal('156.66')),
#  (374, Decimal('98.75')),
#  (375, Decimal('88.80')),
#  (376, Decimal('109.73')),
#  (377, Decimal('93.74')),
#  (378, Decimal('70.82')),
#  (379, Decimal('96.79')),
#  (380, Decimal('132.65')),
#  (381, Decimal('99.68')),
#  (382, Decimal('85.78')),
#  (383, Decimal('93.75')),
#  (384, Decimal('77.79')),
#  (385, Decimal('93.76')),
#  (386, Decimal('109.72')),
#  (387, Decimal('79.78')),
#  (388, Decimal('114.72')),
#  (389, Decimal('119.75')),
#  (390, Decimal('142.69')),
#  (391, Decimal('79.75')),
#  (392, Decimal('91.77')),
#  (393, Decimal('115.71')),
#  (394, Decimal('77.80')),
#  (395, Decimal('57.81')),
#  (396, Decimal('105.74')),
#  (397, Decimal('104.72')),
#  (398, Decimal('73.85')),
#  (399, Decimal('73.82')),
#  (400, Decimal('105.76')),
#  (401, Decimal('62.81')),
#  (402, Decimal('77.81')),
#  (403, Decimal('162.67')),
#  (404, Decimal('133.71')),
#  (405, Decimal('101.70')),
#  (406, Decimal('121.69')),
#  (407, Decimal('104.74')),
#  (408, Decimal('103.73')),
#  (409, Decimal('97.78')),
#  (410, Decimal('167.62')),
#  (411, Decimal('73.76')),
#  (412, Decimal('74.83')),
#  (413, Decimal('65.81')),
#  (414, Decimal('96.77')),
#  (415, Decimal('88.78')),
#  (416, Decimal('113.72')),
#  (417, Decimal('91.78')),
#  (418, Decimal('107.70')),
#  (419, Decimal('86.76')),
#  (420, Decimal('74.80')),
#  (421, Decimal('117.75')),
#  (422, Decimal('96.75')),
#  (423, Decimal('120.74')),
#  (424, Decimal('109.71')),
#  (425, Decimal('98.75')),
#  (426, Decimal('125.74')),
#  (427, Decimal('107.77')),
#  (428, Decimal('73.81')),
#  (429, Decimal('78.84')),
#  (430, Decimal('71.80')),
#  (431, Decimal('92.78')),
#  (432, Decimal('93.80')),
#  (433, Decimal('113.77')),
#  (434, Decimal('122.74')),
#  (435, Decimal('78.77')),
#  (436, Decimal('126.73')),
#  (437, Decimal('85.80')),
#  (438, Decimal('121.70')),
#  (439, Decimal('137.67')),
#  (440, Decimal('83.79')),
#  (441, Decimal('107.73')),
#  (442, Decimal('104.71')),
#  (443, Decimal('93.79')),
#  (444, Decimal('105.72')),
#  (445, Decimal('96.76')),
#  (446, Decimal('109.72')),
#  (447, Decimal('109.73')),
#  (448, Decimal('127.73')),
#  (449, Decimal('80.83')),
#  (450, Decimal('85.75')),
#  (451, Decimal('121.70')),
#  (452, Decimal('99.71')),
#  (453, Decimal('111.77')),
#  (454, Decimal('143.68')),
#  (455, Decimal('85.78')),
#  (456, Decimal('95.76')),
#  (457, Decimal('106.73')),
#  (458, Decimal('66.81')),
#  (459, Decimal('183.63')),
#  (460, Decimal('97.79')),
#  (461, Decimal('90.73')),
#  (462, Decimal('152.69')),
#  (463, Decimal('89.76')),
#  (464, Decimal('67.86')),
#  (465, Decimal('68.84')),
#  (466, Decimal('101.78')),
#  (467, Decimal('134.72')),
#  (468, Decimal('154.66')),
#  (469, Decimal('158.65')),
#  (470, Decimal('157.69')),
#  (471, Decimal('106.74')),
#  (472, Decimal('131.74')),
#  (473, Decimal('122.69')),
#  (474, Decimal('92.75')),
#  (475, Decimal('97.78')),
#  (476, Decimal('87.80')),
#  (477, Decimal('106.79')),
#  (478, Decimal('86.81')),
#  (479, Decimal('134.71')),
#  (480, Decimal('83.81')),
#  (481, Decimal('109.72')),
#  (482, Decimal('125.74')),
#  (483, Decimal('81.83')),
#  (484, Decimal('128.73')),
#  (485, Decimal('112.72')),
#  (486, Decimal('100.77')),
#  (487, Decimal('119.74')),
#  (488, Decimal('95.78')),
#  (489, Decimal('91.81')),
#  (490, Decimal('105.78')),
#  (491, Decimal('120.75')),
#  (492, Decimal('62.85')),
#  (493, Decimal('104.78')),
#  (494, Decimal('135.70')),
#  (495, Decimal('110.76')),
#  (496, Decimal('82.81')),
#  (497, Decimal('121.73')),
#  (498, Decimal('82.76')),
#  (499, Decimal('120.71')),
#  (500, Decimal('96.75')),
#  (501, Decimal('86.81')),
#  (502, Decimal('130.70')),
#  (503, Decimal('99.72')),
#  (504, Decimal('117.75')),
#  (505, Decimal('91.81')),
#  (506, Decimal('123.72')),
#  (507, Decimal('89.77')),
#  (508, Decimal('121.77')),
#  (509, Decimal('86.82')),
#  (510, Decimal('102.77')),
#  (511, Decimal('92.78')),
#  (512, Decimal('115.74')),
#  (513, Decimal('143.70')),
#  (514, Decimal('69.79')),
#  (515, Decimal('110.74')),
#  (516, Decimal('92.76')),
#  (517, Decimal('100.76')),
#  (518, Decimal('108.75')),
#  (519, Decimal('99.78')),
#  (520, Decimal('127.69')),
#  (521, Decimal('80.77')),
#  (522, Decimal('161.68')),
#  (523, Decimal('87.80')),
#  (524, Decimal('81.83')),
#  (525, Decimal('68.82')),
#  (526, Decimal('208.58')),
#  (527, Decimal('81.76')),
#  (528, Decimal('93.80')),
#  (529, Decimal('115.72')),
#  (530, Decimal('75.78')),
#  (531, Decimal('110.77')),
#  (532, Decimal('149.69')),
#  (533, Decimal('132.70')),
#  (534, Decimal('81.78')),
#  (535, Decimal('122.72')),
#  (536, Decimal('109.77')),
#  (537, Decimal('98.76')),
#  (538, Decimal('109.73')),
#  (539, Decimal('84.80')),
#  (540, Decimal('112.76')),
#  (541, Decimal('95.78')),
#  (542, Decimal('84.84')),
#  (543, Decimal('73.80')),
#  (544, Decimal('92.80')),
#  (545, Decimal('84.81')),
#  (546, Decimal('94.76')),
#  (547, Decimal('87.80')),
#  (548, Decimal('63.84')),
#  (549, Decimal('62.84')),
#  (550, Decimal('151.69')),
#  (551, Decimal('75.79')),
#  (552, Decimal('89.80')),
#  (553, Decimal('102.77')),
#  (554, Decimal('95.80')),
#  (555, Decimal('74.83')),
#  (556, Decimal('72.82')),
#  (557, Decimal('63.78')),
#  (558, Decimal('135.72')),
#  (559, Decimal('110.72')),
#  (560, Decimal('129.71')),
#  (561, Decimal('86.75')),
#  (562, Decimal('97.78')),
#  (563, Decimal('99.73')),
#  (564, Decimal('82.78')),
#  (565, Decimal('118.73')),
#  (566, Decimal('130.68')),
#  (567, Decimal('85.80')),
#  (568, Decimal('66.79')),
#  (569, Decimal('113.73')),
#  (570, Decimal('91.75')),
#  (571, Decimal('107.78')),
#  (572, Decimal('100.76')),
#  (573, Decimal('117.72')),
#  (574, Decimal('108.73')),
#  (575, Decimal('109.76')),
#  (576, Decimal('135.68')),
#  (577, Decimal('111.74')),
#  (578, Decimal('95.79')),
#  (579, Decimal('111.73')),
#  (580, Decimal('98.74')),
#  (581, Decimal('97.75')),
#  (582, Decimal('112.76')),
#  (583, Decimal('117.77')),
#  (584, Decimal('114.73')),
#  (585, Decimal('117.76')),
#  (586, Decimal('50.83')),
#  (587, Decimal('102.76')),
#  (588, Decimal('107.73')),
#  (589, Decimal('118.75')),
#  (590, Decimal('108.76')),
#  (591, Decimal('134.73')),
#  (592, Decimal('111.71')),
#  (593, Decimal('101.76')),
#  (594, Decimal('108.77')),
#  (595, Decimal('110.71')),
#  (596, Decimal('73.78')),
#  (597, Decimal('87.77')),
#  (598, Decimal('83.78')),
#  (599, Decimal('78.82'))]

# %%
df = pd.DataFrame(data)

# %%
plt.plot(df[0], df[1])

# %%
cur.close()
