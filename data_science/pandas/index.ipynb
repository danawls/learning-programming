# %% [markdown]
# # Index
#
# address that can access to each data

# %%
import pandas as pd
data = {
    'Name' : ['Cha Chi-soo', 'Jung Dae-man', 'Song Tae-seop', 'Seo Tae-woong', 'Kang Baek-ho', 'Byun Deok-gyu', 'Hwang Tae-san', 'Yoon Dae-hyeop'],
    'School' : ['Buk San High', 'Buk San High', 'Buk San High', 'Buk San High', 'Buk San High', 'Neung Nam High', 'Neung Nam High', 'Neung Nam High'],
    'Height' : [197, 184, 168, 187, 188, 202, 188, 190],
    'Korean' : [90, 40, 80, 40, 15, 80, 55, 100],
    'English' : [85, 35, 75, 60, 20, 100, 65, 85],
    'Math' : [100, 50, 70, 70, 10, 95, 45, 90],
    'Science' : [95, 55, 80, 75, 35, 85, 40, 95],
    'Social' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW Skill' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}
data
df = pd.DataFrame(data, index=[1, 2, 3, 4, 5, 6, 7, 8])
df
# Out:
#              Name          School  Height  Korean  English  Math  Science  \
# 1     Cha Chi-soo    Buk San High     197      90       85   100       95
# 2    Jung Dae-man    Buk San High     184      40       35    50       55
# 3   Song Tae-seop    Buk San High     168      80       75    70       80
# 4   Seo Tae-woong    Buk San High     187      40       60    70       75
# 5    Kang Baek-ho    Buk San High     188      15       20    10       35
# 6   Byun Deok-gyu  Neung Nam High     202      80      100    95       85
# 7   Hwang Tae-san  Neung Nam High     188      55       65    45       40
# 8  Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#    Social    SW Skill
# 1      85      Python
# 2      25        Java
# 3      75  Javascript
# 4      80
# 5      10
# 6      80           C
# 7      35      PYTHON
# 8      95          C#

# %%
df.index
# Out:
# Index([1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %% [markdown]
# # naming index

# %%
df.index.name = "number"

# %%
df
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 4        Seo Tae-woong    Buk San High     187      40       60    70
# 5         Kang Baek-ho    Buk San High     188      15       20    10
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 4            75      80
# 5            35      10
# 6            85      80           C
# 7            40      35      PYTHON
# 8            95      95          C#

# %%
df.reset_index()
# Out:
#    number            Name          School  Height  Korean  English  Math  \
# 0       1     Cha Chi-soo    Buk San High     197      90       85   100
# 1       2    Jung Dae-man    Buk San High     184      40       35    50
# 2       3   Song Tae-seop    Buk San High     168      80       75    70
# 3       4   Seo Tae-woong    Buk San High     187      40       60    70
# 4       5    Kang Baek-ho    Buk San High     188      15       20    10
# 5       6   Byun Deok-gyu  Neung Nam High     202      80      100    95
# 6       7   Hwang Tae-san  Neung Nam High     188      55       65    45
# 7       8  Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#    Science  Social    SW Skill
# 0       95      85      Python
# 1       55      25        Java
# 2       80      75  Javascript
# 3       75      80
# 4       35      10
# 5       85      80           C
# 6       40      35      PYTHON
# 7       95      95          C#

# %%
df.reset_index(drop=True)
# Out:
#              Name          School  Height  Korean  English  Math  Science  \
# 0     Cha Chi-soo    Buk San High     197      90       85   100       95
# 1    Jung Dae-man    Buk San High     184      40       35    50       55
# 2   Song Tae-seop    Buk San High     168      80       75    70       80
# 3   Seo Tae-woong    Buk San High     187      40       60    70       75
# 4    Kang Baek-ho    Buk San High     188      15       20    10       35
# 5   Byun Deok-gyu  Neung Nam High     202      80      100    95       85
# 6   Hwang Tae-san  Neung Nam High     188      55       65    45       40
# 7  Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#    Social    SW Skill
# 0      85      Python
# 1      25        Java
# 2      75  Javascript
# 3      80
# 4      10
# 5      80           C
# 6      35      PYTHON
# 7      95          C#

# %%
df
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 4        Seo Tae-woong    Buk San High     187      40       60    70
# 5         Kang Baek-ho    Buk San High     188      15       20    10
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 4            75      80
# 5            35      10
# 6            85      80           C
# 7            40      35      PYTHON
# 8            95      95          C#

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#              Name          School  Height  Korean  English  Math  Science  \
# 0     Cha Chi-soo    Buk San High     197      90       85   100       95
# 1    Jung Dae-man    Buk San High     184      40       35    50       55
# 2   Song Tae-seop    Buk San High     168      80       75    70       80
# 3   Seo Tae-woong    Buk San High     187      40       60    70       75
# 4    Kang Baek-ho    Buk San High     188      15       20    10       35
# 5   Byun Deok-gyu  Neung Nam High     202      80      100    95       85
# 6   Hwang Tae-san  Neung Nam High     188      55       65    45       40
# 7  Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#    Social    SW Skill
# 0      85      Python
# 1      25        Java
# 2      75  Javascript
# 3      80
# 4      10
# 5      80           C
# 6      35      PYTHON
# 7      95          C#

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#              Name          School  Height  Korean  English  Math  Science  \
# 0     Cha Chi-soo    Buk San High     197      90       85   100       95
# 1    Jung Dae-man    Buk San High     184      40       35    50       55
# 2   Song Tae-seop    Buk San High     168      80       75    70       80
# 3   Seo Tae-woong    Buk San High     187      40       60    70       75
# 4    Kang Baek-ho    Buk San High     188      15       20    10       35
# 5   Byun Deok-gyu  Neung Nam High     202      80      100    95       85
# 6   Hwang Tae-san  Neung Nam High     188      55       65    45       40
# 7  Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#    Social    SW Skill
# 0      85      Python
# 1      25        Java
# 2      75  Javascript
# 3      80
# 4      10
# 5      80           C
# 6      35      PYTHON
# 7      95          C#

# %% [markdown]
# # indexing
# by column

# %%
df.set_index("Name")
# Out:
#                         School  Height  Korean  English  Math  Science  \
# Name
# Cha Chi-soo       Buk San High     197      90       85   100       95
# Jung Dae-man      Buk San High     184      40       35    50       55
# Song Tae-seop     Buk San High     168      80       75    70       80
# Seo Tae-woong     Buk San High     187      40       60    70       75
# Kang Baek-ho      Buk San High     188      15       20    10       35
# Byun Deok-gyu   Neung Nam High     202      80      100    95       85
# Hwang Tae-san   Neung Nam High     188      55       65    45       40
# Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#                 Social    SW Skill
# Name
# Cha Chi-soo         85      Python
# Jung Dae-man        25        Java
# Song Tae-seop       75  Javascript
# Seo Tae-woong       80
# Kang Baek-ho        10
# Byun Deok-gyu       80           C
# Hwang Tae-san       35      PYTHON
# Yoon Dae-hyeop      95          C#

# %%
df
# Out:
#              Name          School  Height  Korean  English  Math  Science  \
# 0     Cha Chi-soo    Buk San High     197      90       85   100       95
# 1    Jung Dae-man    Buk San High     184      40       35    50       55
# 2   Song Tae-seop    Buk San High     168      80       75    70       80
# 3   Seo Tae-woong    Buk San High     187      40       60    70       75
# 4    Kang Baek-ho    Buk San High     188      15       20    10       35
# 5   Byun Deok-gyu  Neung Nam High     202      80      100    95       85
# 6   Hwang Tae-san  Neung Nam High     188      55       65    45       40
# 7  Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#    Social    SW Skill
# 0      85      Python
# 1      25        Java
# 2      75  Javascript
# 3      80
# 4      10
# 5      80           C
# 6      35      PYTHON
# 7      95          C#

# %%
df.set_index("Name", inplace=True)

# %%
df
# Out:
#                         School  Height  Korean  English  Math  Science  \
# Name
# Cha Chi-soo       Buk San High     197      90       85   100       95
# Jung Dae-man      Buk San High     184      40       35    50       55
# Song Tae-seop     Buk San High     168      80       75    70       80
# Seo Tae-woong     Buk San High     187      40       60    70       75
# Kang Baek-ho      Buk San High     188      15       20    10       35
# Byun Deok-gyu   Neung Nam High     202      80      100    95       85
# Hwang Tae-san   Neung Nam High     188      55       65    45       40
# Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#                 Social    SW Skill
# Name
# Cha Chi-soo         85      Python
# Jung Dae-man        25        Java
# Song Tae-seop       75  Javascript
# Seo Tae-woong       80
# Kang Baek-ho        10
# Byun Deok-gyu       80           C
# Hwang Tae-san       35      PYTHON
# Yoon Dae-hyeop      95          C#

# %% [markdown]
# # index sorting

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#                         School  Height  Korean  English  Math  Science  \
# Name
# Byun Deok-gyu   Neung Nam High     202      80      100    95       85
# Cha Chi-soo       Buk San High     197      90       85   100       95
# Hwang Tae-san   Neung Nam High     188      55       65    45       40
# Jung Dae-man      Buk San High     184      40       35    50       55
# Kang Baek-ho      Buk San High     188      15       20    10       35
# Seo Tae-woong     Buk San High     187      40       60    70       75
# Song Tae-seop     Buk San High     168      80       75    70       80
# Yoon Dae-hyeop  Neung Nam High     190     100       85    90       95
#
#                 Social    SW Skill
# Name
# Byun Deok-gyu       80           C
# Cha Chi-soo         85      Python
# Hwang Tae-san       35      PYTHON
# Jung Dae-man        25        Java
# Kang Baek-ho        10
# Seo Tae-woong       80
# Song Tae-seop       75  Javascript
# Yoon Dae-hyeop      95          C#
