# %% [markdown]
# # modify

# %%
import pandas as pd

df = pd.read_csv("score.csv")
df.set_index("number", inplace=True)
df
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 4        Seo Tae-woong    Buk San High     187      40       60    70
# 5         Kang Baek-ho    Buk San High     188      15       20    10
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 4            75      80         NaN
# 5            35      10         NaN
# 6            85      80           C
# 7            40      35      PYTHON
# ...

# %%
df["School"].replace({"Buk San High" : "Fuck high", "Neung Nam High" : "Real Gang High"}, inplace=True)
df
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo       Fuck high     197      90       85   100
# 2         Jung Dae-man       Fuck high     184      40       35    50
# 3        Song Tae-seop       Fuck high     168      80       75    70
# 4        Seo Tae-woong       Fuck high     187      40       60    70
# 5         Kang Baek-ho       Fuck high     188      15       20    10
# 6        Byun Deok-gyu  Real Gang High     202      80      100    95
# 7        Hwang Tae-san  Real Gang High     188      55       65    45
# 8       Yoon Dae-hyeop  Real Gang High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 4            75      80         NaN
# 5            35      10         NaN
# 6            85      80           C
# 7            40      35      PYTHON
# ...

# %%
df["SW Skill"] = df["SW Skill"].str.lower()
df
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo       Fuck high     197      90       85   100
# 2         Jung Dae-man       Fuck high     184      40       35    50
# 3        Song Tae-seop       Fuck high     168      80       75    70
# 4        Seo Tae-woong       Fuck high     187      40       60    70
# 5         Kang Baek-ho       Fuck high     188      15       20    10
# 6        Byun Deok-gyu  Real Gang High     202      80      100    95
# 7        Hwang Tae-san  Real Gang High     188      55       65    45
# 8       Yoon Dae-hyeop  Real Gang High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      python
# 2            55      25        java
# 3            80      75  javascript
# 4            75      80         NaN
# 5            35      10         NaN
# 6            85      80           c
# 7            40      35      python
# ...

# %%
df["School"] = df["School"] + "Ang~"

# %%
df
# Out:
#                   Name              School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo       Fuck highAng~     197      90       85   100
# 2         Jung Dae-man       Fuck highAng~     184      40       35    50
# 3        Song Tae-seop       Fuck highAng~     168      80       75    70
# 4        Seo Tae-woong       Fuck highAng~     187      40       60    70
# 5         Kang Baek-ho       Fuck highAng~     188      15       20    10
# 6        Byun Deok-gyu  Real Gang HighAng~     202      80      100    95
# 7        Hwang Tae-san  Real Gang HighAng~     188      55       65    45
# 8       Yoon Dae-hyeop  Real Gang HighAng~     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      python
# 2            55      25        java
# 3            80      75  javascript
# 4            75      80         NaN
# 5            35      10         NaN
# 6            85      80           c
# ...

# %%
df["Total Score"] = df["Korean"] + df["English"] + df["Math"] + df["Science"] + df["Social"]
df
# Out:
#                   Name              School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo       Fuck highAng~     197      90       85   100
# 2         Jung Dae-man       Fuck highAng~     184      40       35    50
# 3        Song Tae-seop       Fuck highAng~     168      80       75    70
# 4        Seo Tae-woong       Fuck highAng~     187      40       60    70
# 5         Kang Baek-ho       Fuck highAng~     188      15       20    10
# 6        Byun Deok-gyu  Real Gang HighAng~     202      80      100    95
# 7        Hwang Tae-san  Real Gang HighAng~     188      55       65    45
# 8       Yoon Dae-hyeop  Real Gang HighAng~     190     100       85    90
#
#         Science  Social    SW Skill  Total Score
# number
# 1            95      85      python          455
# 2            55      25        java          205
# 3            80      75  javascript          380
# 4            75      80         NaN          325
# ...

# %%
cols = list(df.columns[0: 9])
total = list(df.columns[9:10])
total
cols
# Out:
# ['Name',
#  'School',
#  'Height',
#  'Korean',
#  'English',
#  'Math',
#  'Science',
#  'Social',
#  'SW Skill']

# %%
df = df[ total + cols]
df
# Out:
#         Total Score            Name              School  Height  Korean  \
# number
# 1               455     Cha Chi-soo       Fuck highAng~     197      90
# 2               205    Jung Dae-man       Fuck highAng~     184      40
# 3               380   Song Tae-seop       Fuck highAng~     168      80
# 4               325   Seo Tae-woong       Fuck highAng~     187      40
# 5                90    Kang Baek-ho       Fuck highAng~     188      15
# 6               440   Byun Deok-gyu  Real Gang HighAng~     202      80
# 7               240   Hwang Tae-san  Real Gang HighAng~     188      55
# 8               465  Yoon Dae-hyeop  Real Gang HighAng~     190     100
#
#         English  Math  Science  Social    SW Skill
# number
# 1            85   100       95      85      python
# 2            35    50       55      25        java
# 3            75    70       80      75  javascript
# 4            60    70       75      80         NaN
# ...
