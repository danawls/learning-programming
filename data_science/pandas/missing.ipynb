# %%
import pandas as pd

df = pd.read_csv("score.csv")
df.set_index("number", inplace=True)
df
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 4        Seo Tae-woong    Buk San High     187      40       60    70
# 5         Kang Baek-ho    Buk San High     188      15       20    10
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 4            75      80         NaN
# 5            35      10         NaN
# 6            85      80           C
# 7            40      35      PYTHON
# 8            95      95          C#

# %%
df.fillna("Null")
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 4        Seo Tae-woong    Buk San High     187      40       60    70
# 5         Kang Baek-ho    Buk San High     188      15       20    10
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 4            75      80        Null
# 5            35      10        Null
# 6            85      80           C
# 7            40      35      PYTHON
# 8            95      95          C#

# %%
import numpy as np

# %%
df["School"] = np.nan

# %%
df
# Out:
#                   Name  School  Height  Korean  English  Math  Science  \
# number
# 1          Cha Chi-soo     NaN     197      90       85   100       95
# 2         Jung Dae-man     NaN     184      40       35    50       55
# 3        Song Tae-seop     NaN     168      80       75    70       80
# 4        Seo Tae-woong     NaN     187      40       60    70       75
# 5         Kang Baek-ho     NaN     188      15       20    10       35
# 6        Byun Deok-gyu     NaN     202      80      100    95       85
# 7        Hwang Tae-san     NaN     188      55       65    45       40
# 8       Yoon Dae-hyeop     NaN     190     100       85    90       95
#
#         Social    SW Skill
# number
# 1           85      Python
# 2           25        Java
# 3           75  Javascript
# 4           80         NaN
# 5           10         NaN
# 6           80           C
# 7           35      PYTHON
# 8           95          C#

# %%
df.fillna("Null")
# Out:
#                   Name School  Height  Korean  English  Math  Science  Social  \
# number
# 1          Cha Chi-soo   Null     197      90       85   100       95      85
# 2         Jung Dae-man   Null     184      40       35    50       55      25
# 3        Song Tae-seop   Null     168      80       75    70       80      75
# 4        Seo Tae-woong   Null     187      40       60    70       75      80
# 5         Kang Baek-ho   Null     188      15       20    10       35      10
# 6        Byun Deok-gyu   Null     202      80      100    95       85      80
# 7        Hwang Tae-san   Null     188      55       65    45       40      35
# 8       Yoon Dae-hyeop   Null     190     100       85    90       95      95
#
#           SW Skill
# number
# 1           Python
# 2             Java
# 3       Javascript
# 4             Null
# 5             Null
# 6                C
# 7           PYTHON
# 8               C#

# %%
df["School"] = np.nan

# %%
df
# Out:
#                   Name  School  Height  Korean  English  Math  Science  \
# number
# 1          Cha Chi-soo     NaN     197      90       85   100       95
# 2         Jung Dae-man     NaN     184      40       35    50       55
# 3        Song Tae-seop     NaN     168      80       75    70       80
# 4        Seo Tae-woong     NaN     187      40       60    70       75
# 5         Kang Baek-ho     NaN     188      15       20    10       35
# 6        Byun Deok-gyu     NaN     202      80      100    95       85
# 7        Hwang Tae-san     NaN     188      55       65    45       40
# 8       Yoon Dae-hyeop     NaN     190     100       85    90       95
#
#         Social    SW Skill
# number
# 1           85      Python
# 2           25        Java
# 3           75  Javascript
# 4           80         NaN
# 5           10         NaN
# 6           80           C
# 7           35      PYTHON
# 8           95          C#

# %%
import pandas as pd

df = pd.read_csv("score.csv")
df.set_index("number", inplace=True)
df
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 4        Seo Tae-woong    Buk San High     187      40       60    70
# 5         Kang Baek-ho    Buk San High     188      15       20    10
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 4            75      80         NaN
# 5            35      10         NaN
# 6            85      80           C
# 7            40      35      PYTHON
# 8            95      95          C#

# %%
df.dropna()
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social    SW Skill
# number
# 1            95      85      Python
# 2            55      25        Java
# 3            80      75  Javascript
# 6            85      80           C
# 7            40      35      PYTHON
# 8            95      95          C#

# %%
df.dropna(axis="columns", how="any")
# Out:
#                   Name          School  Height  Korean  English  Math  \
# number
# 1          Cha Chi-soo    Buk San High     197      90       85   100
# 2         Jung Dae-man    Buk San High     184      40       35    50
# 3        Song Tae-seop    Buk San High     168      80       75    70
# 4        Seo Tae-woong    Buk San High     187      40       60    70
# 5         Kang Baek-ho    Buk San High     188      15       20    10
# 6        Byun Deok-gyu  Neung Nam High     202      80      100    95
# 7        Hwang Tae-san  Neung Nam High     188      55       65    45
# 8       Yoon Dae-hyeop  Neung Nam High     190     100       85    90
#
#         Science  Social
# number
# 1            95      85
# 2            55      25
# 3            80      75
# 4            75      80
# 5            35      10
# 6            85      80
# 7            40      35
# 8            95      95

# %%
df['School'] = np.nan

# %%
df
# Out:
#                   Name  School  Height  Korean  English  Math  Science  \
# number
# 1          Cha Chi-soo     NaN     197      90       85   100       95
# 2         Jung Dae-man     NaN     184      40       35    50       55
# 3        Song Tae-seop     NaN     168      80       75    70       80
# 4        Seo Tae-woong     NaN     187      40       60    70       75
# 5         Kang Baek-ho     NaN     188      15       20    10       35
# 6        Byun Deok-gyu     NaN     202      80      100    95       85
# 7        Hwang Tae-san     NaN     188      55       65    45       40
# 8       Yoon Dae-hyeop     NaN     190     100       85    90       95
#
#         Social    SW Skill
# number
# 1           85      Python
# 2           25        Java
# 3           75  Javascript
# 4           80         NaN
# 5           10         NaN
# 6           80           C
# 7           35      PYTHON
# 8           95          C#

# %%
df["School"] = np.nan

# %%
df.loc[2, 1] = "What"
df
# Out:
#                   Name  School  Height  Korean  English  Math  Science  \
# number
# 1          Cha Chi-soo     NaN     197      90       85   100       95
# 2         Jung Dae-man     NaN     184      40       35    50       55
# 3        Song Tae-seop     NaN     168      80       75    70       80
# 4        Seo Tae-woong     NaN     187      40       60    70       75
# 5         Kang Baek-ho     NaN     188      15       20    10       35
# 6        Byun Deok-gyu     NaN     202      80      100    95       85
# 7        Hwang Tae-san     NaN     188      55       65    45       40
# 8       Yoon Dae-hyeop     NaN     190     100       85    90       95
#
#         Social    SW Skill     1
# number
# 1           85      Python   NaN
# 2           25        Java  What
# 3           75  Javascript   NaN
# 4           80         NaN   NaN
# 5           10         NaN   NaN
# 6           80           C   NaN
# 7           35      PYTHON   NaN
# 8           95          C#   NaN

# %%
df
# Out:
#                   Name  School  Height  Korean  English  Math  Science  \
# number
# 1          Cha Chi-soo     NaN     197      90       85   100       95
# 2         Jung Dae-man     NaN     184      40       35    50       55
# 3        Song Tae-seop     NaN     168      80       75    70       80
# 4        Seo Tae-woong     NaN     187      40       60    70       75
# 5         Kang Baek-ho     NaN     188      15       20    10       35
# 6        Byun Deok-gyu     NaN     202      80      100    95       85
# 7        Hwang Tae-san     NaN     188      55       65    45       40
# 8       Yoon Dae-hyeop     NaN     190     100       85    90       95
#
#         Social    SW Skill     1
# number
# 1           85      Python   NaN
# 2           25        Java  What
# 3           75  Javascript   NaN
# 4           80         NaN   NaN
# 5           10         NaN   NaN
# 6           80           C   NaN
# 7           35      PYTHON   NaN
# 8           95          C#   NaN

# %%
df.iloc[3, 2] = np.nan

# %%
df
# Out:
#                   Name  School  Height  Korean  English  Math  Science  \
# number
# 1          Cha Chi-soo     NaN   197.0      90       85   100       95
# 2         Jung Dae-man     NaN   184.0      40       35    50       55
# 3        Song Tae-seop     NaN   168.0      80       75    70       80
# 4        Seo Tae-woong     NaN     NaN      40       60    70       75
# 5         Kang Baek-ho     NaN   188.0      15       20    10       35
# 6        Byun Deok-gyu     NaN   202.0      80      100    95       85
# 7        Hwang Tae-san     NaN   188.0      55       65    45       40
# 8       Yoon Dae-hyeop     NaN   190.0     100       85    90       95
#
#         Social    SW Skill     1
# number
# 1           85      Python   NaN
# 2           25        Java  What
# 3           75  Javascript   NaN
# 4           80         NaN   NaN
# 5           10         NaN   NaN
# 6           80           C   NaN
# 7           35      PYTHON   NaN
# 8           95          C#   NaN

# %%
df["School"] = np.nan

# %%
df.dropna(axis="columns", how="any", inplace=True)
df
# Out:
#                   Name  Korean  English  Math  Science  Social
# number
# 1          Cha Chi-soo      90       85   100       95      85
# 2         Jung Dae-man      40       35    50       55      25
# 3        Song Tae-seop      80       75    70       80      75
# 4        Seo Tae-woong      40       60    70       75      80
# 5         Kang Baek-ho      15       20    10       35      10
# 6        Byun Deok-gyu      80      100    95       85      80
# 7        Hwang Tae-san      55       65    45       40      35
# 8       Yoon Dae-hyeop     100       85    90       95      95

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.rcParams["font.size"] = 5

# %%
plt.plot(df["Name"], df["Korean"])
plt.plot(df["Name"], df["English"])
plt.title("Korean score and English score")
plt.figure(figsize=(8, 5), dpi=500)
plt.savefig("foo.png")
plt.show()
